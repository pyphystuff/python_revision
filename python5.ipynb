# %% [markdown]
# # Axis Properties

# %%
#importing modules
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D
import matplotlib.pyplot as plt
#other useful modules
import numpy as np
import sympy as s

# %% [markdown]
# # Harmonic oscillator solution:
#
# # $ x(t) = cos(wt+\alpha)$
# # $w= \sqrt{(k/m)}$

# %%
#code from book

fig, ax = plt.subplots(figsize=(8, 3), subplot_kw={'facecolor': "#ebf5ff"})

x = np.linspace(0, 50, 500)
ax.plot(x, np.sin(x) * np.exp(-x/10), lw=2)

ax.set_xlabel("x", labelpad=5,
              fontsize=18, fontname='serif', color="blue")
ax.set_ylabel("f(x)", labelpad=15,
              fontsize=18, fontname='serif', color="blue")
ax.set_title("axis labels and title example", loc='left',
             fontsize=16, fontname='serif', color="blue")

fig.tight_layout()
fig.savefig("ch4-axis-labels.pdf")

# %%
#lets define some constants
k=5
m=4
w= np.sqrt(k/m)
alpha= 15

# %%
#Basic labeling
#lets use the new code to improve this one
fig, ax = plt.subplots(figsize=(8, 4),subplot_kw={'facecolor': "#ebf5ff"} ) #adding some color to ther axe

#functions
x = np.linspace(-20, 20, 500)
y1 = np.cos(w*x +alpha)
y2 = np.cos(w*x +30)

#plots
ax.plot(x, y1)
ax.plot(x, y2)

#new axes and title


ax.set_xlabel("x", labelpad=5,
              fontsize=18, fontname='serif', color="blue")
ax.set_ylabel("f(x)", labelpad=15,
              fontsize=18, fontname='serif', color="red")
ax.set_title("Harmonic Oscillator", loc='center',
             fontsize=18, fontname='serif', color="black")

fig.tight_layout()

# %%
#example from the book

x = np.linspace(0, 30, 500)
y = np.sin(x) * np.exp(-x/10)

fig, axes = plt.subplots(1, 3, figsize=(9, 3), subplot_kw={'facecolor': "#ebf5ff"})

axes[0].plot(x, y, lw=2)
axes[0].set_xlim(-5, 35)
axes[0].set_ylim(-1, 1)
axes[0].set_title("set_xlim / set_y_lim")

axes[1].plot(x, y, lw=2)
axes[1].axis('tight')
axes[1].set_title("axis('tight')")

axes[2].plot(x, y, lw=2)
axes[2].axis('equal')
axes[2].set_title("axis('equal')")

fig.savefig("ch4-axis-ranges.pdf")

# %%
#Basic labeling
#lets use the new code to improve this one
#axes in plurar and we need to define extra plots inside subplots: 1 column, 3 row: (1,3)
fig, axes = plt.subplots(1,3,figsize=(8, 4),subplot_kw={'facecolor': "#ebf5ff"} ) 

#functions
x = np.linspace(-20, 20, 500)
y1 = np.cos(w*x +alpha)
y2 = np.cos(w*x +30)

#plots
ax.plot(x, y1)
ax.plot(x, y2)

#new axes and title


ax.set_xlabel("x", labelpad=5,
              fontsize=18, fontname='serif', color="blue")
ax.set_ylabel("f(x)", labelpad=15,
              fontsize=18, fontname='serif', color="red")
ax.set_title("Harmonic Oscillator", loc='center',
             fontsize=18, fontname='serif', color="black")



#diferente axes in the same figure



axes[0].plot(x, y1, lw=2)
axes[0].set_xlim(-5, 35)
axes[0].set_ylim(-1, 1)
axes[0].set_title("set_xlim / set_y_lim")

axes[1].plot(x,y1, lw=2)
axes[1].axis('tight')
axes[1].set_title("axis('tight')")

axes[2].plot(x, y1, lw=2)
axes[2].axis('equal')
axes[2].set_title("axis('equal')")
# Out:
# Text(0.5, 1.0, "axis('equal')")

# %%
#ticks (example from the book)

x = np.linspace(-2 * np.pi, 2 * np.pi, 500)
y = np.sin(x) * np.exp(-x**2/20)

fig, axes = plt.subplots(1, 4, figsize=(12, 3))

axes[0].plot(x, y, lw=2)
axes[0].set_title("default ticks")

axes[1].plot(x, y, lw=2)
axes[1].set_yticks([-1, 0, 1])
axes[1].set_xticks([-5, 0, 5])
axes[1].set_title("set_xticks")

axes[2].plot(x, y, lw=2)
axes[2].xaxis.set_major_locator(mpl.ticker.MaxNLocator(4))
axes[2].yaxis.set_major_locator(mpl.ticker.FixedLocator([-1, 0, 1]))
axes[2].xaxis.set_minor_locator(mpl.ticker.MaxNLocator(8))
axes[2].yaxis.set_minor_locator(mpl.ticker.MaxNLocator(8))
axes[2].set_title("set_major_locator")

axes[3].plot(x, y, lw=2)
axes[3].set_yticks([-1, 0, 1])
axes[3].set_xticks([-2 * np.pi, -np.pi, 0, np.pi, 2 * np.pi])
axes[3].set_xticklabels(['$-2\pi$', '$-\pi$', 0, r'$\pi$', r'$2\pi$'])
axes[3].xaxis.set_minor_locator(mpl.ticker.FixedLocator([-3 * np.pi / 2, -np.pi/2, 0, np.pi/2, 3 * np.pi/2]))
axes[3].yaxis.set_minor_locator(mpl.ticker.MaxNLocator(4))
axes[3].set_title("set_xticklabels")

fig.tight_layout()
fig.savefig("ch4-axis-ticks.pdf")

# %%
#lets damp this (with ticks)
#damping factor
d=0.09

x = np.linspace(-20, 20, 100)
y1 = np.exp(-d*x)*np.cos(w*x +alpha)

y2 = np.exp(-d*x)*np.cos(w*x +30)
y4 = np.exp(-d*x)
y3 = -np.exp(-d*x)



fig, axes = plt.subplots(1, 4, figsize=(12, 3)) #defining the number of plots

axes[0].plot(x, y1,y2, lw=2)
axes[0].set_title("default ticks")

axes[1].plot(x, y2, lw=2)
axes[1].set_yticks([-4, 0,5, 6]) #we can change where we want the limits 
axes[1].set_xticks([-5, 0, 5])
axes[1].set_title("set_xticks")

axes[2].plot(x,y1, lw=2)
axes[2].xaxis.set_major_locator(mpl.ticker.MaxNLocator(4))
axes[2].yaxis.set_major_locator(mpl.ticker.FixedLocator([-1, 0, 1]))
axes[2].xaxis.set_minor_locator(mpl.ticker.MaxNLocator(8))
axes[2].yaxis.set_minor_locator(mpl.ticker.MaxNLocator(8))
axes[2].set_title("set_major_locator")

axes[3].plot(x,y1, lw=2)
axes[3].set_yticks([-1, 0, 1])
axes[3].set_xticks([-2 * np.pi, -np.pi, 0, np.pi, 2 * np.pi])
axes[3].set_xticklabels(['$-2\pi$', '$-\pi$', 0, r'$\pi$', r'$2\pi$'])
axes[3].xaxis.set_minor_locator(mpl.ticker.FixedLocator([-3 * np.pi / 2, -np.pi/2, 0, np.pi/2, 3 * np.pi/2]))
axes[3].yaxis.set_minor_locator(mpl.ticker.MaxNLocator(4))
axes[3].set_title("set_xticklabels")

fig.tight_layout()

# %% [markdown]
# # Grids

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))
x = np.linspace(-2 * np.pi, 2 * np.pi, 500)
y = np.sin(x) * np.exp(-x**2/20)

x_major_ticker = mpl.ticker.MultipleLocator(4)
x_minor_ticker = mpl.ticker.MultipleLocator(1)
y_major_ticker = mpl.ticker.MultipleLocator(0.5)
y_minor_ticker = mpl.ticker.MultipleLocator(0.25)

for ax in axes:
    ax.plot(x, y, lw=2)
    ax.xaxis.set_major_locator(x_major_ticker)
    ax.yaxis.set_major_locator(y_major_ticker)
    ax.xaxis.set_minor_locator(x_minor_ticker)
    ax.yaxis.set_minor_locator(y_minor_ticker)

axes[0].set_title("default grid")
axes[0].grid()

axes[1].set_title("major/minor grid")
axes[1].grid(color="blue", which="both", linestyle=':', linewidth=0.5)

axes[2].set_title("individual x/y major/minor grid")
axes[2].grid(color="grey", which="major", axis='x', linestyle='-', linewidth=0.5)
axes[2].grid(color="grey", which="minor", axis='x', linestyle=':', linewidth=0.25)
axes[2].grid(color="grey", which="major", axis='y', linestyle='-', linewidth=0.5)

fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

x = np.linspace(-10, 10, 1000)
#potential energy

y1 = (1/2)*k*(np.cos(w*x +alpha))**2

#kinetic energy

y2 = (1/2)*m*w*(np.sin(w*x +alpha))**2


ax.plot(x, y1,label ="U")
ax.plot(x, y2,label ="K")
ax.legend()   #always call the legend


ax.set_ylabel("ENERGY")
ax.set_xlabel("x")
# Out:
# Text(0.5, 0, 'x')

# %%
#space phase



fig, ax = plt.subplots(figsize=(8, 4))

x = np.linspace(-10, 10, 100)
#potential energy

y1 = np.cos(w*x +alpha)

#kinetic energy

y2 = w*np.sin(w*x +alpha) #velocity


#ax.plot(x, y1)
ax.plot(y1, y2)


ax.set_ylabel("y label")
ax.set_xlabel("x label")
# Out:
# Text(0.5, 0, 'x label')

# %%
#lets combine some exercices: a figure with labels and backgorund color


#changing some colors with facecolor: 
fig = plt.figure(figsize=(8, 2.5), facecolor="#eafff5")
left, bottom, width, height = 0.1, 0.1, 0.8, 0.8
ax = fig.add_axes((left, bottom, width, height),
         facecolor="#17becf") #changed color here also

x = np.linspace(-10,10,100)
y = np.sin(x)*np.exp(-x)


ax.plot(x, y, color='red', label ="y=sin(x)*exp(x)")


ax.set_ylabel("y label")
ax.set_xlabel("x label")

ax.legend()   #always call the legend

# %%
#latex format is available

fig, ax = plt.subplots(figsize=(12, 3))

ax.set_yticks([])
ax.set_xticks([])
ax.set_xlim(-0.5, 3.5)
ax.set_ylim(-0.05, 0.25)
ax.axhline(0)

ax.text(0, 0.1, "Text label", fontsize=14, family="serif")

ax.plot(1, 0, 'o')
ax.annotate("Annotation",
            fontsize=14, family="serif",
            xy=(1, 0), xycoords='data',
            xytext=(+20, +50), textcoords='offset points', 
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3, rad=.5"))

ax.text(2, 0.1, r"Equation: $i\hbar\partial_t \Psi = \hat{H}\Psi$", fontsize=14, family="serif")

fig.savefig("ch4-text-annotation.pdf")

# %%
#latex format is available

fig, ax = plt.subplots(figsize=(12, 3))

ax.set_yticks([])
ax.set_xticks([])
ax.set_xlim(-0.5, 3.5)
ax.set_ylim(-0.05, 0.25)
ax.axhline(0)                      #constant line
#ax.axhline(0.1)

ax.text(0.7, 0.1, "Text label", fontsize=14, family="serif") #text
ax.text(0, 0.18, "Text label2", fontsize=18, family="times") #text
ax.text(0, 0.21, "Text label3", fontsize=10, family="arial") 


ax.plot(1, 0, 'o')
ax.annotate("Annotation",
            fontsize=14, family="serif",
            xy=(1, 0), xycoords='data',
            xytext=(+20, +50), textcoords='offset points', 
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3, rad=.5"))



#ax.text(2, 0.1, r"Equation: $i\hbar\partial_t \Psi = \hat{H}\Psi$", fontsize=14, family="serif")
ax.text(2, 0.1, r"Equation: $i\hbar\partial_{th} X = \hat{H}\Theta$", fontsize=14, family="serif")
# Out:
# Text(2, 0.1, 'Equation: $i\\hbar\\partial_{th} X = \\hat{H}\\Theta$')

# %%
x = np.linspace(-2 * np.pi, 2 * np.pi, 100)



fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(x, np.cos(x), linewidth=4, color="red", label='cos(x)')

ax.plot(0, 1, 'o')
ax.annotate("cos(0)=1",
            fontsize=14, family="serif",
            xy=(0,1), xycoords='data',
            xytext=(+20, +50), textcoords='offset points', 
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3, rad=.5"))
# Out:
# Text(20, 50, 'cos(0)=1')
