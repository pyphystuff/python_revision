# %% [markdown]
# # Axis Properties, log plots and scientific notation

# %%
#importing modules
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D
import matplotlib.pyplot as plt
#other useful modules
import numpy as np
import sympy as s

# %% [markdown]
# # Harmonic oscillator solution:
#
# # $ x(t) = cos(wt+\alpha)$
# # $w= \sqrt{(k/m)}$

# %%
#code from book

fig, ax = plt.subplots(figsize=(8, 3), subplot_kw={'facecolor': "#ebf5ff"})

x = np.linspace(0, 50, 500)
ax.plot(x, np.sin(x) * np.exp(-x/10), lw=2)

ax.set_xlabel("x", labelpad=5,
              fontsize=18, fontname='serif', color="blue")
ax.set_ylabel("f(x)", labelpad=15,
              fontsize=18, fontname='serif', color="blue")
ax.set_title("axis labels and title example", loc='left',
             fontsize=16, fontname='serif', color="blue")

fig.tight_layout()
fig.savefig("ch4-axis-labels.pdf")

# %%
#lets define some constants
k=5
m=4
w= np.sqrt(k/m)
alpha= 15

# %%
#Basic labeling
#lets use the new code to improve this one
fig, ax = plt.subplots(figsize=(8, 4),subplot_kw={'facecolor': "#ebf5ff"} ) #adding some color to ther axe

#functions
x = np.linspace(-20, 20, 500)
y1 = np.cos(w*x +alpha)
y2 = np.cos(w*x +30)

#plots
ax.plot(x, y1)
ax.plot(x, y2)

#new axes and title


ax.set_xlabel("x", labelpad=5,
              fontsize=18, fontname='serif', color="blue")
ax.set_ylabel("f(x)", labelpad=15,
              fontsize=18, fontname='serif', color="red")
ax.set_title("Harmonic Oscillator", loc='center',
             fontsize=18, fontname='serif', color="black")

fig.tight_layout()

# %% [markdown]
# # Lets use scientific notation

# %%
#example from the book

fig, axes = plt.subplots(1, 2, figsize=(8, 3))

x = np.linspace(0, 1e5, 100)
y = x ** 2

axes[0].plot(x, y, 'b.')
axes[0].set_title("default labels", loc='right')

axes[1].plot(x, y, 'b')
axes[1].set_title("scientific notation labels", loc='right')

#mplticker controls the scientific notation

formatter = mpl.ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)            #setting scientific notation
formatter.set_powerlimits((-1,1))          #limiting the powers
axes[1].xaxis.set_major_formatter(formatter)
axes[1].yaxis.set_major_formatter(formatter)

fig.tight_layout()

# %%
#example from the book

fig, axes = plt.subplots(1, 2, figsize=(8, 3))

x = np.linspace(0, 1e5, 100)
y = x ** 2

axes[0].plot(x, y, 'b.')
axes[0].set_title("default labels", loc='right')

axes[1].plot(x, y, 'b')
axes[1].set_title("scientific notation labels", loc='right')

#mplticker controls the scientific notation

formatter = mpl.ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)            #setting scientific notation
formatter.set_powerlimits((-1,1))          #limiting the powers
axes[1].xaxis.set_major_formatter(formatter)
axes[1].yaxis.set_major_formatter(formatter)

fig.tight_layout()

# %%
#example from the book

fig, axes = plt.subplots(1, 2, figsize=(8, 3))

x = np.linspace(0, 1e5, 500)
y1 = np.cos(x)*x**2
y2 = np.cos(x)*x**2


axes[0].plot(x, y1, 'b.')
axes[0].set_title("default labels", loc='right')

axes[1].plot(x, y1, 'b')
axes[1].set_title("scientific notation labels", loc='right')

#mplticker controls the scientific notation

formatter = mpl.ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)            #setting scientific notation
formatter.set_powerlimits((-1,1))          #limiting the powers
axes[1].xaxis.set_major_formatter(formatter)
axes[1].yaxis.set_major_formatter(formatter)

fig.tight_layout()

# %% [markdown]
# # Lets play with a curve

# %%
#Basic labeling
#lets use the new code to improve this one
fig, ax = plt.subplots(figsize=(8, 4),subplot_kw={'facecolor': "#ebf5ff"} ) #adding some color to ther axe

#functions
x = np.linspace(-20, 2e5, 500)
y1 = x
y2 = np.cos(x)

ax.plot(x, y1)
ax.plot(x, y2)

#axes[0].plot(x, y1, 'b.')
#axes[0].set_title("default labels", loc='right')

#axes[1].plot(x, y2, 'b')
#axes[1].set_title("scientific notation labels", loc='right')

#mplticker controls the scientific notation

formatter = mpl.ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)            #setting scientific notation
formatter.set_powerlimits((-1,1))          #limiting the powers
ax.xaxis.set_major_formatter(formatter)
ax.yaxis.set_major_formatter(formatter)


#plots
fig.tight_layout()

# %% [markdown]
# # Log Plots

# %%
#example from the book

fig, axes = plt.subplots(1, 3, figsize=(12, 3))

x = np.linspace(0, 1e3, 100)
y1, y2 = x**3, x**4

axes[0].set_title('loglog')
axes[0].loglog(x, y1, 'b', x, y2, 'r')

axes[1].set_title('semilogy')
axes[1].semilogy(x, y1, 'b', x, y2, 'r')

axes[2].set_title('plot / set_xscale / set_yscale')
axes[2].plot(x, y1, 'b', x, y2, 'r')
axes[2].set_xscale('log')
axes[2].set_yscale('log')

fig.tight_layout()

# %%
#lets damp this (with ticks)
#damping factor
d=0.09

x = np.linspace(-20, 20, 100)
y1 = np.exp(-d*x)*np.cos(w*x +alpha)

y2 = np.exp(-d*x)*np.cos(w*x +30)
y4 = np.exp(-d*x)
y3 = -np.exp(-d*x)



fig, axes = plt.subplots(1, 4, figsize=(12, 3)) #defining the number of plots


axes[0].set_title('loglog')
axes[0].loglog(x, y1, 'b', x, y2, 'r')
#only y axis
axes[1].set_title('semilogy')
axes[1].semilogy(x, y1, 'b', x, y2, 'r')

#alternative way with the sam result of axes 0...here we manipulate the scale and not the plot
axes[2].set_title('plot / set_xscale / set_yscale')
axes[2].plot(x, y1, 'b', x, y2, 'r')
axes[2].set_xscale('log')
axes[2].set_yscale('log')


#only x axis
axes[3].set_title('semilogX')
axes[3].semilogx(x, y1, 'b', x, y2, 'r')

fig.tight_layout()

# %% [markdown]
# # Twin axes

# %%
fig, ax1 = plt.subplots(figsize=(8, 4))

r = np.linspace(0, 5, 100)
a = 4 * np.pi * r ** 2  # area
v = (4 * np.pi / 3) * r ** 3  # volume


ax1.set_title("surface area and volume of a sphere", fontsize=16)
ax1.set_xlabel("radius [m]", fontsize=16)

ax1.plot(r, a, lw=2, color="blue")
ax1.set_ylabel(r"surface area ($m^2$)", fontsize=16, color="blue")
for label in ax1.get_yticklabels():
    label.set_color("blue")
    
ax2 = ax1.twinx()
ax2.plot(r, v, lw=2, color="red")
ax2.set_ylabel(r"volume ($m^3$)", fontsize=16, color="red")
for label in ax2.get_yticklabels():
    label.set_color("red")
    
fig.tight_layout()

# %%
#now with amplitude and velocity of the harmonic oscillator
fig, ax1 = plt.subplots(figsize=(8, 4))


x = np.linspace(-20, 20, 500)
a  = np.cos(w*x +alpha) # amplitude
v =  -w*np.sin(w*x +alpha) # velocity





ax1.set_title("Amplitude and velocity of an harmonic oscillator", fontsize=16)
ax1.set_xlabel("distance[m]", fontsize=16)

ax1.plot(x, a, lw=2, color="blue")
ax1.set_ylabel(r"Amplitude ($m$)", fontsize=16, color="blue")
for label in ax1.get_yticklabels():
    label.set_color("blue")
    
ax2 = ax1.twinx()
ax2.plot(x, v, lw=2, color="red")
ax2.set_ylabel(r"velocity ($m/s$)", fontsize=16, color="red")
for label in ax2.get_yticklabels():
    label.set_color("red")
    
fig.tight_layout()

# %% [markdown]
# # Splines

# %%
x = np.linspace(-10, 10, 500)
y = np.sin(x) / x

fig, ax = plt.subplots(figsize=(8, 4))

ax.plot(x, y, linewidth=2)

# remove top and right spines
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# remove top and right spine ticks
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# move bottom and left spine to x = 0 and y = 0
ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))
    
ax.set_xticks([-10, -5, 5, 10])
ax.set_yticks([0.5, 1])

# give each label a solid background of white, to not overlap with the plot line
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_bbox({'facecolor': 'white',
                    'edgecolor': 'white'})
    
fig.tight_layout()

# %%
x = np.linspace(-10, 10, 500)
y = np.cos(w*x +alpha) 

fig, ax = plt.subplots(figsize=(8, 4))

ax.plot(x, y, linewidth=2)

# remove top and right spines
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# remove top and right spine ticks
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# move bottom and left spine to x = 0 and y = 0
ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))
    
ax.set_xticks([-10, -5, 5, 10])
ax.set_yticks([0.5, 1])

# give each label a solid background of white, to not overlap with the plot line
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_bbox({'facecolor': 'white',
                    'edgecolor': 'white'})
